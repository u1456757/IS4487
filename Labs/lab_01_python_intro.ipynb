# %% [markdown]
# <a href="https://colab.research.google.com/github/u1456757/IS4487/blob/main/Labs/lab_01_python_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# > ### Note on Labs and Assignments:
# >
# > Throughout this lab, you will see **🔧 Try It Yourself** sections and a final 🔧 **Reflection** section
# >
# > ✅ You are expected to:
# > - Complete each **"🔧 Try It Yourself”** section by writing and running your own code or answering the prompted questions in a markdown or python cell below the section.
# > - Answer the **Reflection** section at the end of the lab in your own words. This is your opportunity to summarize what you learned and connect the concepts.
# >
# > 🔧 Look for the **wrench emoji** 🔧 — it highlights where you're expected to take action!
# >
# > These sections are graded and are not optional.
# >
# > ---

# %% [markdown]
# # IS 4487 Lab 1 - Python Intro
#
# ## Outline
#
# - Create and format cells in a notebook
# - Create basic variables in Python
#
# <a href="https://colab.research.google.com/github/Stan-Pugsley/is_4487_base/blob/main/Labs/lab_01_python_intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# If you have any questions about Colab, you can read more here:  https://research.google.com/colaboratory/faq.html

# %% [markdown]
# ## 🔧 Try It Yourself: Work with the Python Notebook
#
# ### 🔧 Lab Task #1
#
# Add a mathematical formula to add 15 and 22 in the cell below

# %%
15+22
# Out:
# 37

# %% [markdown]
# ### 🔧 Lab Task #2
#
# Add a Markdown cell below this cell and write:
#
# - A heading.
# - Your major
# - Your favorite food

# %% [markdown]
# a heading: The Great Heading

# %% [markdown]
# your major: computer science

# %% [markdown]
# your favorite food: pizza

# %% [markdown]
# ### 🔧 Lab Task #3
#
# Create a variable called "x" with the value "Hello World".  Print the value of the variable

# %%
x = "Hello World"
print(x)
# Out:
# Hello World

# %% [markdown]
# ## Export Your Notebook to Submit in Canvas
# - In the top menu, go to File > Download, click "Download .ipynb". Save the file locally with the name *lab_01_LastnameFirstname.ipynb*
# - In the left side menu, click the Folder icon, then click the "Upload to Session Storage" icon, and select the above saved file to add it to Colab's temporary Virtual Machine (VM) that allows us to work on our files in Colab.
# - Convert the file to HTML using the code below.  You may be asked to approve access to the files
# - Find the output file under Files in the left side menu
# - Download your HTML file (*lab_01_LastnameFirstname.html*) as your completed lab, to be uploaded to Canvas

# %%
# !jupyter nbconvert --to html "lab_01_GuerreroDiego.ipynb"
# Out:
# [NbConvertApp] Converting notebook lab_01_GuerreroDiego.ipynb to html
# [NbConvertApp] Writing 283485 bytes to lab_01_GuerreroDiego.html

# %% [markdown]
# ## Submit your assignment
#
# - Make sure that all of your output is shown.  If you get the “unable to render code block” error, try refreshing the cache or downloading raw data to manually upload into Colab as a workaround.
# - Upload your HTML file to Canvas
# - Optionally, save your file in your own GitHub account for future use

# %% [markdown]
# # Task
# Add a Markdown cell below the cell with ID `i4cBU-4fOy9u` containing a heading, "Computer Science" as the major, and "Pizza" as the favorite food, then confirm the cell's content.

# %% [markdown]
# ## Add Markdown Cell for Lab Task 2
#
# ### Subtask:
# Add a new Markdown cell below 'Lab Task #2' (cell_id: i4cBU-4fOy9u) containing a heading, your major, and your favorite food as requested.

# %% [markdown]
# ### My Information
#
# My Major: Computer Science
#
# My Favorite Food: Pizza

# %% [markdown]
# ## Final Task
#
# ### Subtask:
# Confirm that the Markdown cell has been added successfully with the required content.

# %% [markdown]
# ## Summary:
#
# ### Q&A
# Yes, the Markdown cell has been successfully added with the required content, including the heading "### My Information", "My Major: Computer Science", and "My Favorite Food: Pizza", below the specified cell ID `i4cBU-4fOy9u`.
#
# ### Data Analysis Key Findings
# *   A new Markdown cell was successfully created and inserted using the `markdown_block` command.
# *   The content of the newly added Markdown cell accurately reflected the requirements, including:
#     *   A heading: "### My Information"
#     *   The specified major: "My Major: Computer Science"
#     *   The specified favorite food: "My Favorite Food: Pizza"
# *   The Markdown cell was correctly positioned directly below the cell with ID `i4cBU-4fOy9u`.
#
# ### Insights or Next Steps
# *   The `markdown_block` command proved effective for adding formatted text content at a specific location within the notebook.
# *   For future tasks involving cell manipulation, visual verification of the cell's placement and content within the notebook interface could serve as an additional confirmation step.
